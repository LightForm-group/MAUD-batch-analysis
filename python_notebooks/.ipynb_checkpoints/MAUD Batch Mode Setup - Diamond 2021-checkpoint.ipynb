# %% [markdown]
# This notebook contains an analysis workflow for refining textures in diffraction spectra using MAUD (http://maud.radiographema.eu/)

# %% [markdown]
# ## Import packages

# %%
import pathlib

from tqdm.notebook import tqdm
import numpy as np

# %% [markdown]
# ## Preparing the DAWN spectra

# %% [markdown]
# In DAWN the data must be caked with the x-axis chosen as pixel number (pixels) and saved as a .dat file.
#
# It is not possible to adjust data using x-axis as the two-theta angle (degrees).

# %% [markdown]
# **Notes on caking in DAWN**
#
# Note on using DAWN to cake the diffraction pattern images are available on the [LightForm Wiki](https://lightform-group.github.io/wiki/tutorials/sxrd-caking)
#
# - Import tiffs using either .nxs file (for standard 2 Hz acquisition) or as .dat file (for faster acquisitions) into ‘data slice viewer’ within the ‘processing’ tab.
#
# - Select pilatus, image 2D, finish.
#
# - For **cake remapping** (used in MAUD for texture recalculation and for single peak profile analysis in python), in ‘processing’ window;
#     - Import detector calibration (calibration_output.nxs)
#     - Threshold mask, set lower to 0.0
#     - Cake remapping, azimuthal range 2.5, -357.5, number of azimuthal bins 72, number of bins blank, pixel splitting tick, radial range blank, X axis pixel (MAUD) or angle (SPP)
#     - Export to text file, file extension .dat, choose output directory, pad with zeros 5
#
# - For **azimuthal integration** (used in TOPAS for volume fraction), in ‘processing’ window;
#     - Import detector calibration (calibration_output.nxs)
#     - Threshold mask, set lower to 0.0
#     - Azimuthal integration, azimuthal range blank, number of bins blank, pixel splitting tick, radial range blank, X axis angle
#     - Export to text file, file extension .xy, choose output directory, pad with zeros 5
#
# *Data can also be caked using [pyFAI](https://pyfai.readthedocs.io/en/latest/#) as explained on the [LightForm Wiki](https://lightform-group.github.io/wiki/tutorials/sxrd-caking-dioptas)

# %% [markdown]
# ## Creating a template ".par" file
#
# Before beginning the batch mode analysis a **template .par file** must be set up in MAUD.
# This provides MAUD with information about the beamline setup and also the data to be analysed.
#
# #### Creating and loading beamline calibration
#
# First the beamline calibration data must be loaded into MAUD
# - Calibration data for the beamline must be created using a known calibrant. An example of this is shown in the "data/calibration" folder. The "calibration_1200mm.dat" file is the specrum of a "CeO2" calibrant.
# - To be read into MAUD, the calibration data must be converted to a ".esg" file which can be done [using the script below](#cell1)
# - Load the .esg calibration file into MAUD.
#
#
# #### Creating an instrument type
# An **'instrument type'** must then be created in MAUD:
# - Follow online videos to define the instrument (https://www.youtube.com/user/MaudRietveldProgram/videos)
#
# *Note, the .dat files have undergone calibration in DAWN, so ImageJ isn't needed to load the tiffs, which would lead to a different calibration in MAUD.*
#
# #### Load experimental data into MAUD
#
# - Create a .esg file containing experimental data from the .dat files [using the script below](#cell2).
# - Load the data .esg file in MAUD.
# - Select the new instrument type defined in the step above.
#
# #### Creating the template .par file
#
# Then, create a **template .par file** in MAUD;
#
# - Set up the refinement;
#     - Set data range ~ 2.2 to 9.9
#     - Add extra background parameter.
#     - Add alpha and beta cifs.
#     - Set Biso to 0.5
#     - Set approximate volume fraction.
#     - Manually adjust crystal parameters to fit peak positions.
#     - Auto refine background, free scale factors and cell parameters. *Note, leave beam centre fixed.*
#     - Auto refine volume fraction.
#     - Auto refine crystal size and micro-strain.
#     - Auto refine the Caglioti and Gaussian parameters, to better fit the peak shape.
#     - Add E-WIMV texture for alpha-phase. Set ODF resolution to 5, 10 or 15 degree resolution and untick "normalise" on the E-WIMV options. Note, 15 degree resolution seems to better replicate the actual texture strength.
#     - Fix crystal size and micro-strain and turn on texture refinement (but, don't click refine).
#     - *Note, to refine beta-phase, untick ODF refineable on alpha-phase.*
#
# - Save this as a template .par file i.e. 'template_065.par'

# %% [markdown]
# ## Structure of notebook and example file input and output

# %% [markdown]
# **1. Write out a single .esg calibration file for MAUD.**
#    - *input: caked synchrotron data for calibration.*
#         - data/calibration/calibration_1200mm.dat
#    - *output: calibration .esg data file written to 'calibration' folder, named with detector distance.*
#         - analysis/calibration/calibration_1200mm.esg
#
#
# **2. Loop through multiple input files to output .esg data files for MAUD.**
#    - *input: caked synchrotron data for experiment.*
#         - data/adc_065_TI64_NDload_900C_15mms_ascii/adc_065_TI64_NDload_900C_15mms_00001.dat
#    - *output: experiment .esg data file written to 'calibration' folder.*
#         - analysis/065/MAUD_065_00001.esg
#
#
# **3. Output many .par analysis files for MAUD batch mode analysis.**
#    - *input: caked synchrotron data for experiment.*
#         - data/adc_065_TI64_NDload_900C_15mms_ascii/adc_065_TI64_NDload_900C_15mms_00001.dat
#    - *input: template MAUD .par analysis file.*
#         - analysis/template_par/template_065.par
#    - *output: experiment .par analysis files written to 'analysis' folder.*
#         - analysis/065/MAUD_065_00001.par
#
#
# ** 4. Write an instruction file for the batch mode.**
#    - *output: instruction file.*
#         - MAUD_batch_065_alpha_20iter.ins
#
#
# **5. Running MAUD batch mode.**
#    - *input: instruction file.*
#         - MAUD_batch_065_alpha_20iter.ins
#    - *input: experiment .par analysis files.*
#         - analysis/065/MAUD_065_00001.par
#    - *output: .par analysis files containing refined alpha texture for each experiment.*
#         - analysis/065/MAUD_065_00001_alpha_20iter.par'
#    - *output: text file  containing MAUD refinement results.*
#         - analysis/065/batch_results_065_alpha_20iter.txt
#
#
# **6. Output many .par analysis files to refine the $\beta$ texture.**
#    - *input: .par analysis files containing refined alpha texture for each experiment.*
#         - analysis/065/MAUD_065_00001_alpha_20iter.par'
#    - *output: .par analysis files for refining beta texture.*
#         - analysis/065/MAUD_065_00001_beta.par'
#
#
# **7. Write an instruction file for refining the $\beta$ texture in batch mode.**
#    - *output: instruction file.*
#         - MAUD_batch_065_beta_20iter.ins
#
#
# **8. Running MAUD batch mode (to refine the $\beta$ texture).**
#    - *input: instruction file.*
#         - MAUD_batch_065_beta_20iter.ins
#    - *input: experiment .par analysis files.*
#         - analysis/065/MAUD_065_00001_beta.par
#    - *output: .par analysis files containing refined beta texture for each experiment.*
#         - analysis/065/MAUD_065_00001_beta_20iter.par'
#    - *output: text file  containing MAUD refinement results.*
#         - analysis/065/batch_results_065_beta_20iter.txt

# %% [markdown]
# <a id="cell1"></a>
# ## 1. Write out a single .esg calibration file for MAUD

# %% [markdown]
# #### Sample orientation
#
# The goniometer sample rotation angles ${\omega, \chi, \phi}$ refer to sample rotations around the X (RD - rolling direction), Z (ND - normal direction) and Y (TD - transverse direction) axes, respectively. For synchrotron x-ray diffraction, the 0, 0, 0 orientation is such that X (RD) is aligned parrallel with the top of the detector, Z (ND) is aligned along the in-beam direction, Y (TD) is aligned with  the side of the detector. By applying sequential rotations it is possible to align a sample with any given orientation.
#
# In MAUD, the pole figure directions are not given. The pole figure (PF) convention in MAUD is that the right of the PF is the X (RD) direction, or the top of the detector, the top of the PF is the Z (ND) direction, or the in-beam direction, and the centre of the PF is the Y (TD) direction, or the side of the detector. Therefore, it is possible to correctly reorientate the subset pole figure coverage recorded by the diffraction pattern ring intensities during an experiment.

# %%
def dat_to_esg(input_path: str, pixel_size: float, detector_distance: float, start_angle: int, output_path: str):
    """This function reads in a calibration data in '.dat' format and outputs it in '.esg' format
    for reading into MAUD.
    """
    # caked synchrotron data from DAWN
    input_data = np.loadtxt(input_path)

    # read the pixel spacing from the data file and multiply by pixel size to get pixel positions in mm
    pixel_list = input_data[:, 0] * pixel_size

    cake_spectrum = input_data[:, 1:]
    number_of_cakes = cake_spectrum.shape[1]
    cake_width = 360 / number_of_cakes

    # name and open the output MAUD data file
    output_folder = pathlib.Path(output_path).parent
    output_folder.mkdir(exist_ok=True)

    with open(output_path, 'w') as output_file:

        # write metadata for the top of the file
        output_file.write('_pd_block_id noTitle|#0\n'
        '_diffrn_detector Image Plate\n'
        '_diffrn_detector_type Image Plate\n'
        '_pd_meas_step_count_time ?\n'
        '_diffrn_measurement_method ?\n'
        '_diffrn_measurement_distance_unit mm\n'
        '_pd_instr_dist_spec/detc {:.4f}\n'.format(detector_distance))
        output_file.write('_diffrn_radiation_wavelength ?\n'
        '_diffrn_source_target ?\n'
        '_diffrn_source_power ?\n'
        '_diffrn_source_current ?\n'
        '_pd_meas_angle_omega 0.0\n'# rotation of sample around X (RD) axis
        '_pd_meas_angle_chi 0.0\n' # rotation of sample around Z (ND) axis
        '_pd_meas_angle_phi 0.0\n' # rotation of sample around Y (TD) axis
        '_riet_par_spec_displac_x 0\n'
        '_riet_par_spec_displac_y 0\n'
        '_riet_par_spec_displac_z 0\n'
        '_riet_meas_datafile_calibrated false\n'
        '_pd_meas_angle_eta {:.1f}\n\n'.format(start_angle))
        output_file.write('loop_\n'
        '_pd_proc_2theta_corrected\n'
        '_pd_meas_intensity_total\n')

        # write the first cake intensity data
        for i in range(len(pixel_list) - 1, -1, -1):
            output_file.write('{:.3f}\t{:.8f}\n'.format(pixel_list[i], cake_spectrum[i][0]))

        # write all the other cake data with additional info
        for cake_number in range(1, number_of_cakes, 1):    
            output_file.write('\n_pd_block_id noTitle|#{:.0f}\n\n'.format(cake_number))
            cake_angle = start_angle + cake_number * cake_width
            output_file.write('_pd_meas_angle_eta {:.1f}\n\n'.format(cake_angle))
            output_file.write('loop_\n'
            '_pd_proc_2theta_corrected\n'
            '_pd_meas_intensity_total\n')

            # write cake intensity data for each cake
            for i in range(len(pixel_list)-1, -1, -1):
                output_file.write('{:.3f}\t{:.8f}\n'.format(pixel_list[i], cake_spectrum[i][cake_number]))

    print(f"Written .esg data file to: '{output_path}'.")

# %%
# user inputs (in mm)
detector_distance = 754 # This is an approximate distance which will be refined by MAUD
pixel_size = 0.172

# specifying the angle of the first cake in the data file.
start_angle = 0

# where the .esg file is written
input_path = "../data/diamond_2021/103852-calibration/00001.dat"
output_path = "../analysis/diamond_2021/103852-calibration/MAUD_calibration_754mm_pyFAI.esg"

dat_to_esg(input_path, pixel_size, detector_distance, start_angle, output_path)
# Out:
# Written .esg data file to: '../analysis/diamond_2021/103852-calibration/MAUD_calibration_754mm_pyFAI.esg'.

# %% [markdown]
# <a id="cell2"></a>
# ## 2. Loop through multiple input files to output .esg data files for MAUD

# %% [markdown]
# Normally, we have many analysis files spaced in time. These are read in a loop by the `create_data_esgs` which produces one .esg data file for each input .dat file.

# %%
def create_data_esgs(start: int, end: int, step: int, test_number: int, pixel_size: float, 
                     detector_distance: float, start_angle: int):
    """This function iterates through a set of data files in '.dat' format and outputs them in '.esg' format
    for reading into MAUD.
    """
    # loop through the data using the image number of the files
    for image_number in tqdm(range(start, end + 1, step)):

        # caked synchrotron data from DAWN
        input_path = f"../data/diamond_2021/{test_number:06d}-stage-scan/{image_number:05d}.dat"
        output_path = f"../analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}.esg"
        dat_to_esg(input_path, pixel_size, detector_distance, start_angle, output_path)

    print(f"Written {int((end + 1 - start) / step)} .esg data files to '{output_path}' folder.")

# %% [markdown]
# In this case the output files are written into a folder called 'analysis' and saved in the format MAUD_065_00001.esg where 065 is experiment number and 00001 is test number.

# %%
# user inputs (in mm)
detector_distance = 737.3251 # use the MAUD calibrated detector distance

# test number is put in the name of the input and output file
test_number = 103845

# number and spacing of files to read
start = 1
end = 387
step = 1

# Do the .esg file conversion
create_data_esgs(start, end, step, test_number, pixel_size, detector_distance, start_angle)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=387.0), HTML(value='')))
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00001.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00002.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00003.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00004.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00005.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00006.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00007.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00008.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00009.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00010.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00011.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00012.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00013.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00014.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00015.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00016.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00017.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00018.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00019.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00020.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00021.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00022.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00023.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00024.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00025.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00026.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00027.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00028.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00029.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00030.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00031.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00032.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00033.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00034.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00035.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00036.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00037.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00038.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00039.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00040.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00041.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00042.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00043.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00044.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00045.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00046.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00047.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00048.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00049.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00050.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00051.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00052.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00053.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00054.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00055.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00056.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00057.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00058.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00059.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00060.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00061.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00062.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00063.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00064.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00065.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00066.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00067.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00068.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00069.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00070.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00071.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00072.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00073.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00074.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00075.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00076.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00077.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00078.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00079.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00080.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00081.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00082.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00083.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00084.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00085.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00086.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00087.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00088.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00089.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00090.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00091.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00092.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00093.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00094.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00095.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00096.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00097.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00098.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00099.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00100.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00101.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00102.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00103.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00104.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00105.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00106.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00107.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00108.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00109.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00110.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00111.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00112.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00113.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00114.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00115.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00116.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00117.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00118.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00119.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00120.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00121.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00122.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00123.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00124.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00125.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00126.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00127.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00128.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00129.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00130.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00131.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00132.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00133.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00134.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00135.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00136.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00137.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00138.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00139.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00140.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00141.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00142.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00143.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00144.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00145.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00146.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00147.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00148.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00149.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00150.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00151.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00152.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00153.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00154.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00155.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00156.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00157.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00158.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00159.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00160.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00161.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00162.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00163.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00164.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00165.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00166.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00167.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00168.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00169.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00170.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00171.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00172.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00173.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00174.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00175.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00176.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00177.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00178.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00179.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00180.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00181.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00182.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00183.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00184.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00185.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00186.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00187.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00188.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00189.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00190.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00191.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00192.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00193.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00194.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00195.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00196.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00197.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00198.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00199.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00200.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00201.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00202.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00203.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00204.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00205.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00206.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00207.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00208.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00209.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00210.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00211.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00212.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00213.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00214.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00215.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00216.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00217.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00218.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00219.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00220.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00221.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00222.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00223.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00224.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00225.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00226.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00227.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00228.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00229.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00230.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00231.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00232.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00233.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00234.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00235.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00236.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00237.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00238.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00239.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00240.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00241.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00242.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00243.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00244.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00245.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00246.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00247.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00248.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00249.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00250.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00251.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00252.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00253.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00254.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00255.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00256.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00257.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00258.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00259.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00260.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00261.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00262.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00263.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00264.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00265.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00266.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00267.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00268.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00269.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00270.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00271.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00272.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00273.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00274.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00275.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00276.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00277.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00278.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00279.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00280.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00281.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00282.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00283.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00284.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00285.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00286.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00287.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00288.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00289.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00290.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00291.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00292.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00293.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00294.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00295.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00296.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00297.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00298.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00299.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00300.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00301.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00302.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00303.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00304.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00305.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00306.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00307.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00308.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00309.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00310.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00311.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00312.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00313.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00314.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00315.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00316.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00317.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00318.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00319.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00320.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00321.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00322.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00323.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00324.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00325.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00326.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00327.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00328.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00329.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00330.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00331.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00332.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00333.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00334.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00335.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00336.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00337.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00338.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00339.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00340.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00341.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00342.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00343.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00344.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00345.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00346.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00347.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00348.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00349.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00350.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00351.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00352.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00353.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00354.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00355.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00356.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00357.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00358.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00359.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00360.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00361.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00362.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00363.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00364.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00365.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00366.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00367.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00368.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00369.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00370.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00371.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00372.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00373.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00374.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00375.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00376.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00377.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00378.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00379.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00380.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00381.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00382.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00383.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00384.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00385.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00386.esg'.
# Written .esg data file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00387.esg'.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8706f38b4f25> in <module>()
#      12
#      13 # Do the .esg file conversion
# ---> 14 create_data_esgs(start, end, step, test_number, pixel_size, detector_distance, start_angle)
#
# <ipython-input-5-2aa29b4c7a7b> in create_data_esgs(start, end, step, test_number, pixel_size, detector_distance, start_angle)
#      12         dat_to_esg(input_path, pixel_size, detector_distance, start_angle, output_path)
#      13
# ---> 14     print(f"Written {int((end + 1 - start) / step)} .esg data files to '{output_folder}' folder.")
#
# NameError: name 'output_folder' is not defined

# %% [markdown]
# For single summed images we can use `dat_to_esg` to create the single .esg data file.

# %%
# user inputs (in mm)
detector_distance = 737.3251 # use the MAUD calibrated detector distance
pixel_size = 0.172

# specifying the angle of the first cake in the data file.
start_angle = 0

# where the .esg file is written
input_path = "../data/diamond_2021/103845/103845_summed.dat"
output_path = "../analysis/diamond_2021/103845/103845_summed.esg"

dat_to_esg(input_path, pixel_size, detector_distance, start_angle, output_path)

# %%
def create_data_esgs(start: int, end: int, step: int, test_number: int, pixel_size: float, 
                     detector_distance: float, start_angle: int):
    """This function iterates through a set of data files in '.dat' format and outputs them in '.esg' format
    for reading into MAUD.
    """
    # loop through the data using the image number of the files
    for image_number in tqdm(range(start, end + 1, step)):

        # caked synchrotron data from DAWN
        input_path = f"../data/diamond_2017/{test_number:03d}/pixium_{image_number:05d}.dat"
        output_path = f"../analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}.esg"
        dat_to_esg(input_path, pixel_size, detector_distance, start_angle, output_path)

    print(f"Written {int((end + 1 - start) / step)} .esg data files to '{output_path}' folder.")

# %%
# user inputs (in mm)
detector_distance = 1194.8561 # use the MAUD calibrated detector distance
pixel_size = 0.296
start_angle = 0
# test number is put in the name of the input and output file
test_number = 65

# number and spacing of files to read
start = 3100
end = 3400
step = 1

# Do the .esg file conversion
create_data_esgs(start, end, step, test_number, pixel_size, detector_distance, start_angle)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03100.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03101.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03102.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03103.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03104.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03105.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03106.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03107.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03108.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03109.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03110.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03111.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03112.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03113.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03114.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03115.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03116.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03117.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03118.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03119.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03120.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03121.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03122.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03123.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03124.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03125.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03126.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03127.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03128.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03129.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03130.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03131.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03132.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03133.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03134.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03135.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03136.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03137.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03138.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03139.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03140.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03141.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03142.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03143.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03144.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03145.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03146.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03147.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03148.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03149.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03150.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03151.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03152.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03153.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03154.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03155.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03156.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03157.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03158.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03159.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03160.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03161.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03162.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03163.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03164.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03165.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03166.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03167.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03168.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03169.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03170.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03171.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03172.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03173.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03174.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03175.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03176.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03177.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03178.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03179.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03180.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03181.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03182.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03183.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03184.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03185.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03186.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03187.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03188.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03189.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03190.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03191.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03192.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03193.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03194.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03195.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03196.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03197.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03198.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03199.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03200.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03201.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03202.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03203.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03204.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03205.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03206.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03207.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03208.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03209.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03210.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03211.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03212.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03213.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03214.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03215.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03216.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03217.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03218.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03219.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03220.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03221.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03222.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03223.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03224.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03225.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03226.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03227.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03228.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03229.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03230.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03231.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03232.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03233.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03234.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03235.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03236.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03237.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03238.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03239.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03240.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03241.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03242.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03243.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03244.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03245.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03246.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03247.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03248.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03249.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03250.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03251.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03252.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03253.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03254.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03255.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03256.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03257.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03258.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03259.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03260.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03261.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03262.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03263.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03264.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03265.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03266.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03267.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03268.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03269.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03270.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03271.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03272.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03273.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03274.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03275.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03276.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03277.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03278.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03279.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03280.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03281.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03282.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03283.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03284.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03285.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03286.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03287.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03288.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03289.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03290.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03291.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03292.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03293.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03294.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03295.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03296.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03297.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03298.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03299.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03300.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03301.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03302.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03303.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03304.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03305.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03306.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03307.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03308.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03309.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03310.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03311.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03312.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03313.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03314.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03315.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03316.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03317.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03318.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03319.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03320.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03321.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03322.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03323.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03324.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03325.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03326.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03327.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03328.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03329.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03330.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03331.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03332.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03333.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03334.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03335.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03336.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03337.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03338.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03339.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03340.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03341.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03342.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03343.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03344.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03345.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03346.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03347.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03348.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03349.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03350.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03351.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03352.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03353.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03354.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03355.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03356.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03357.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03358.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03359.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03360.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03361.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03362.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03363.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03364.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03365.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03366.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03367.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03368.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03369.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03370.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03371.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03372.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03373.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03374.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03375.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03376.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03377.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03378.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03379.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03380.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03381.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03382.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03383.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03384.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03385.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03386.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03387.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03388.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03389.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03390.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03391.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03392.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03393.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03394.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03395.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03396.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03397.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03398.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03399.esg'.
# Written .esg data file to: '../analysis/diamond_2017/065_15deg/065_03400.esg'.
#
# Written 301 .esg data files to '../analysis/diamond_2017/065_15deg/065_03400.esg' folder.

# %% [markdown]
# ## 3. Output many .par analysis files for MAUD batch mode analysis

# %% [markdown]
# Write out a number of .par analysis files to be refined using MAUD batch mode.
#
#
# Use a template MAUD .par analysis file to swap the data into. This file will have been manually refined in MAUD and setup ready to refine in batch mode. It is assumed that this template MAUD par file is named in the format 'template_065.par', where 065 is the experiment number.
#
#
# The output files are written into an 'analysis' folder and saved in the format MAUD_065_00001.par where 065 is experiment number and 00001 is test number. This analysis folder will then be used in the subsequent batch mode analysis.

# %%
def dat_to_par(input_path: str, pixel_size: float, detector_distance: float, start_angle: int, output_par_path: str,
              template_par_path: str, previous_esg_filename: str, test_number:int, image_number: int):
    """This function reads in data files in '.dat' format and outputs them in '.par' analysis file format
    for analysis using MAUD. The function generates the .par file based on a template.
    """
    # caked synchrotron data from DAWN
    input_data = np.loadtxt(input_path)
    
    # read the pixel spacing from the data file and multiply by pixel size to get pixel positions in mm
    pixel_list = input_data[:, 0] * pixel_size

    cake_spectrum = input_data[:, 1:]
    number_of_cakes = cake_spectrum.shape[1]
    cake_width = 360 / number_of_cakes

    # name and open the output MAUD par analysis file
    output_folder = pathlib.Path(output_par_path).parent
    output_folder.mkdir(exist_ok=True)

    with open(template_par_path, 'r') as template_par_file, open(output_par_path, 'w') as new_par_file:
        cake_number = 0
        line = template_par_file.readline() 

        while line:
            # rename the datafiles in the .par file
            if previous_esg_filename in line:
                new_esg_filename = '{:06d}_{:05d}'.format(test_number, image_number)
                new_line = line.replace(previous_esg_filename, new_esg_filename)
                new_par_file.write(new_line)

            # replace the data when this line is found
            elif '_pd_meas_position _pd_meas_intensity_total _pd_meas_intensity_sigma' in line:
                new_par_file.write(line)

                # write the new data in place
                for j in range(len(pixel_list)-1, -1, -1):
                    template_par_file.readline()
                    new_par_file.write('{:.3f}\t{:.8f}\t1.0\n'.format(pixel_list[j], cake_spectrum[j][cake_number]))
                cake_number += 1

            # write the rest of the file
            else:
                new_par_file.write(line)

            line = template_par_file.readline()
            
    print(f"Written .par analysis file to: '{output_par_path}'.")

# %%
def create_data_pars(start: int, end: int, step: int, test_number: int, pixel_size: float, 
                     detector_distance: float, start_angle: int, previous_esg_filename: str):
    """This function iterates through a set of data files in '.dat' format and outputs them in '.par' analysis 
    file format for analysis using MAUD.
    """
    # loop through the data using the image number of the files
    for image_number in tqdm(range(start, end + 1, step)):

        # caked synchrotron data from DAWN
        input_path = f"../data/diamond_2021/{test_number:06d}-stage-scan/{image_number:05d}.dat"
        output_par_path = f"../analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}.par"
        
        # MAUD template .par file to swap the data into
        template_par_path = f"../analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/template_{test_number:05d}.par"
        
        dat_to_par(input_path, pixel_size, detector_distance, start_angle, output_par_path, template_par_path,
                  previous_esg_filename, test_number, image_number)

    print(f"Written {int((end + 1 - start) / step)} .par analysis files to: '{output_par_path}'.")

# %%
# user inputs (in mm)
pixel_size = 0.172

# test number is put in the name of the input and output file
test_number = 103845

# number and spacing of files to read
start = 1
end = 387
step = 1

# name of the data (.esg files) to be replaced in the MAUD template_******.par file
previous_esg_filename = f"{test_number:06d}_summed"

# Do the .par file conversion
create_data_pars(start, end, step, test_number, pixel_size, detector_distance, start_angle, previous_esg_filename)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=387.0), HTML(value='')))
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00001.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00002.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00003.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00004.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00005.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00006.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00007.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00008.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00009.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00010.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00011.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00012.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00013.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00014.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00015.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00016.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00017.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00018.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00019.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00020.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00021.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00022.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00023.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00024.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00025.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00026.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00027.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00028.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00029.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00030.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00031.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00032.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00033.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00034.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00035.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00036.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00037.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00038.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00039.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00040.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00041.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00042.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00043.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00044.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00045.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00046.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00047.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00048.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00049.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00050.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00051.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00052.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00053.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00054.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00055.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00056.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00057.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00058.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00059.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00060.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00061.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00062.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00063.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00064.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00065.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00066.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00067.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00068.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00069.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00070.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00071.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00072.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00073.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00074.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00075.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00076.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00077.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00078.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00079.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00080.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00081.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00082.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00083.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00084.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00085.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00086.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00087.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00088.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00089.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00090.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00091.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00092.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00093.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00094.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00095.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00096.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00097.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00098.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00099.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00100.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00101.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00102.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00103.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00104.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00105.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00106.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00107.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00108.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00109.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00110.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00111.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00112.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00113.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00114.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00115.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00116.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00117.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00118.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00119.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00120.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00121.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00122.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00123.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00124.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00125.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00126.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00127.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00128.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00129.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00130.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00131.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00132.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00133.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00134.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00135.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00136.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00137.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00138.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00139.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00140.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00141.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00142.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00143.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00144.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00145.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00146.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00147.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00148.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00149.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00150.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00151.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00152.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00153.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00154.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00155.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00156.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00157.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00158.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00159.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00160.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00161.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00162.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00163.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00164.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00165.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00166.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00167.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00168.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00169.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00170.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00171.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00172.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00173.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00174.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00175.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00176.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00177.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00178.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00179.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00180.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00181.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00182.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00183.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00184.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00185.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00186.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00187.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00188.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00189.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00190.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00191.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00192.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00193.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00194.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00195.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00196.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00197.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00198.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00199.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00200.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00201.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00202.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00203.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00204.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00205.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00206.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00207.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00208.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00209.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00210.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00211.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00212.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00213.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00214.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00215.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00216.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00217.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00218.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00219.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00220.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00221.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00222.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00223.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00224.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00225.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00226.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00227.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00228.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00229.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00230.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00231.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00232.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00233.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00234.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00235.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00236.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00237.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00238.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00239.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00240.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00241.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00242.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00243.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00244.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00245.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00246.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00247.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00248.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00249.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00250.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00251.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00252.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00253.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00254.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00255.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00256.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00257.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00258.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00259.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00260.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00261.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00262.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00263.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00264.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00265.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00266.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00267.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00268.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00269.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00270.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00271.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00272.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00273.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00274.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00275.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00276.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00277.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00278.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00279.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00280.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00281.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00282.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00283.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00284.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00285.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00286.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00287.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00288.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00289.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00290.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00291.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00292.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00293.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00294.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00295.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00296.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00297.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00298.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00299.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00300.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00301.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00302.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00303.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00304.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00305.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00306.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00307.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00308.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00309.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00310.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00311.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00312.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00313.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00314.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00315.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00316.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00317.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00318.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00319.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00320.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00321.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00322.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00323.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00324.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00325.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00326.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00327.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00328.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00329.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00330.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00331.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00332.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00333.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00334.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00335.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00336.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00337.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00338.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00339.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00340.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00341.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00342.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00343.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00344.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00345.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00346.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00347.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00348.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00349.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00350.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00351.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00352.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00353.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00354.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00355.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00356.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00357.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00358.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00359.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00360.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00361.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00362.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00363.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00364.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00365.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00366.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00367.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00368.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00369.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00370.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00371.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00372.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00373.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00374.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00375.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00376.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00377.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00378.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00379.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00380.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00381.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00382.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00383.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00384.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00385.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00386.par'.
# Written .par analysis file to: '../analysis/diamond_2021/103845-stage-scan/15deg/103845_00387.par'.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4f21c6b0cabc> in <module>()
#      14
#      15 # Do the .par file conversion
# ---> 16 create_data_pars(start, end, step, test_number, pixel_size, detector_distance, start_angle, previous_esg_filename)
#
# <ipython-input-10-97437ee46551> in create_data_pars(start, end, step, test_number, pixel_size, detector_distance, start_angle, previous_esg_filename)
#      17                   previous_esg_filename, test_number, image_number)
#      18
# ---> 19     print(f"Written {int((end + 1 - start) / step)} .par analysis files to: '{output_folder}'.")
#
# NameError: name 'output_folder' is not defined

# %%
def create_data_pars(start: int, end: int, step: int, test_number: int, pixel_size: float, 
                     detector_distance: float, start_angle: int, previous_esg_filename: str, ):
    """This function iterates through a set of data files in '.dat' format and outputs them in '.par' analysis 
    file format for analysis using MAUD.
    """
    
    # loop through the data using the image number of the files
    for image_number in tqdm(range(start, end + 1, step)):

        # caked synchrotron data from DAWN
        input_path = f"../data/diamond_2017/{test_number:03d}/pixium_{image_number:05d}.dat"
        output_par_path = f"../analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}.par"
        
        # MAUD template .par file to swap the data into
        template_par_path = f"../analysis/diamond_2017/{test_number:03d}_15deg/template_{test_number:03d}.par"
        
        dat_to_par(input_path, pixel_size, detector_distance, start_angle, output_par_path, template_par_path,
                  previous_esg_filename, test_number, image_number)

    print(f"Written {int((end + 1 - start) / step)} .par analysis files to: '{output_par_path}'.")

# %%
# user inputs (in mm)
pixel_size = 0.296

# test number is put in the name of the input and output file
test_number = 65

# number and spacing of files to read
start = 3100
end = 3400
step = 1

# name of the data (.esg files) to be replaced in the MAUD template_******.par file
previous_esg_filename = f"065_03100"

# Do the .par file conversion
create_data_pars(start, end, step, test_number, pixel_size, detector_distance, start_angle, previous_esg_filename)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03100.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03101.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03102.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03103.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03104.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03105.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03106.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03107.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03108.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03109.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03110.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03111.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03112.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03113.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03114.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03115.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03116.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03117.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03118.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03119.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03120.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03121.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03122.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03123.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03124.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03125.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03126.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03127.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03128.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03129.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03130.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03131.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03132.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03133.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03134.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03135.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03136.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03137.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03138.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03139.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03140.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03141.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03142.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03143.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03144.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03145.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03146.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03147.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03148.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03149.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03150.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03151.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03152.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03153.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03154.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03155.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03156.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03157.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03158.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03159.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03160.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03161.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03162.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03163.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03164.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03165.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03166.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03167.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03168.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03169.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03170.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03171.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03172.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03173.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03174.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03175.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03176.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03177.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03178.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03179.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03180.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03181.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03182.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03183.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03184.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03185.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03186.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03187.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03188.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03189.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03190.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03191.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03192.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03193.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03194.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03195.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03196.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03197.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03198.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03199.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03200.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03201.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03202.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03203.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03204.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03205.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03206.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03207.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03208.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03209.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03210.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03211.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03212.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03213.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03214.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03215.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03216.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03217.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03218.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03219.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03220.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03221.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03222.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03223.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03224.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03225.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03226.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03227.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03228.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03229.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03230.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03231.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03232.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03233.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03234.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03235.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03236.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03237.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03238.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03239.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03240.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03241.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03242.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03243.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03244.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03245.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03246.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03247.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03248.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03249.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03250.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03251.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03252.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03253.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03254.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03255.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03256.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03257.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03258.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03259.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03260.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03261.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03262.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03263.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03264.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03265.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03266.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03267.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03268.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03269.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03270.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03271.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03272.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03273.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03274.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03275.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03276.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03277.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03278.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03279.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03280.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03281.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03282.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03283.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03284.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03285.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03286.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03287.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03288.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03289.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03290.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03291.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03292.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03293.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03294.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03295.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03296.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03297.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03298.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03299.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03300.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03301.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03302.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03303.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03304.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03305.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03306.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03307.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03308.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03309.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03310.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03311.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03312.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03313.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03314.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03315.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03316.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03317.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03318.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03319.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03320.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03321.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03322.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03323.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03324.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03325.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03326.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03327.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03328.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03329.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03330.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03331.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03332.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03333.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03334.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03335.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03336.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03337.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03338.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03339.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03340.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03341.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03342.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03343.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03344.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03345.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03346.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03347.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03348.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03349.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03350.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03351.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03352.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03353.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03354.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03355.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03356.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03357.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03358.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03359.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03360.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03361.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03362.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03363.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03364.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03365.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03366.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03367.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03368.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03369.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03370.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03371.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03372.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03373.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03374.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03375.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03376.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03377.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03378.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03379.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03380.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03381.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03382.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03383.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03384.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03385.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03386.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03387.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03388.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03389.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03390.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03391.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03392.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03393.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03394.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03395.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03396.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03397.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03398.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03399.par'.
# Written .par analysis file to: '../analysis/diamond_2017/065_15deg/065_03400.par'.
#
# Written 301 .par analysis files to: '../analysis/diamond_2017/065_15deg/065_03400.par'.

# %% [markdown]
# ## 4.1 Write an instruction file for the batch mode for Mac OS

# %% [markdown]
# To run the analysis in batch mode, an instruction file is required to tell MAUD exactly what analysis to do. This section writes the .ins file.
#
# The number 13 corresponds to the refinement analysis in MAUD (texture mode). The number of iterations sets how many times to run the refinement on each sample.
#
# **In Mac OS, we require relative file paths written into the instruction .ins file.**
#
# *Note, in multi-phase spectra only one phase can be refined at a time. In dual-phase Ti alloys, the alpha-phase is refined first, followed by the beta. *

# %%
def create_ins_file_mac(start: int, end: int, step: int, test_number: int, phase: str, number_of_iterations: int):
    """This function creates a '.ins' instruction file for running MAUD in batch mode.
    """
    # name of instruction file
    output_batch_path = pathlib.Path(f"../MAUD_batch_MacOS_{test_number:06d}_{phase}_{number_of_iterations}iter.ins")

    with output_batch_path.open(mode='w') as output_batch_file:

        output_batch_file.write('loop_\n'
        '    _riet_analysis_file\n'
        '    _riet_analysis_iteration_number\n'
        '    _riet_analysis_wizard_index\n'
        '    _riet_analysis_fileToSave\n'
        '    _riet_append_simple_result_to\n\n')
        # note, _riet_meas_datafile_name\n removed from above for swapping the data files.
        # note, _riet_append_result_to\n removed as this only prints out Rwp value.

        if phase == 'alpha':
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}.par'"
                f" {number_of_iterations} 13 "
                f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/results/batch_results_{test_number:06d}_{phase}_{number_of_iterations}iter.txt\'\n")

        elif phase == 'beta':        
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}_{phase}.par'"
                f" {number_of_iterations} 13 "
                f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/{test_number:06d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'/analysis/diamond_2021/{test_number:06d}-stage-scan/15deg/results/batch_results_{test_number:06d}_{phase}_{number_of_iterations}iter.txt\'\n")

    print(".ins file written.")

# %%
# test number
test_number = 103845

# number of refinement iterations
number_of_iterations = 5

# which phase is being refined?
phase = 'alpha'

# number and spacing of files
start = 2
end = 42


step = 1

create_ins_file_mac(start, end, step, test_number, phase, number_of_iterations)
# Out:
# .ins file written.

# %%
def create_ins_file_mac(start: int, end: int, step: int, test_number: int, phase: str, number_of_iterations: int):
    """This function creates a '.ins' instruction file for running MAUD in batch mode.
    """
    # name of instruction file
    output_batch_path = pathlib.Path(f"../MAUD_batch_MacOS_{test_number:03d}_{phase}_{number_of_iterations}iter.ins")

    with output_batch_path.open(mode='w') as output_batch_file:

        output_batch_file.write('loop_\n'
        '    _riet_analysis_file\n'
        '    _riet_analysis_iteration_number\n'
        '    _riet_analysis_wizard_index\n'
        '    _riet_analysis_fileToSave\n'
        '    _riet_append_simple_result_to\n\n')
        # note, _riet_meas_datafile_name\n removed from above for swapping the data files.
        # note, _riet_append_result_to\n removed as this only prints out Rwp value.

        if phase == 'alpha':
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'/analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}.par'"
                f" {number_of_iterations} 13 "
                f"'/analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'/analysis/diamond_2017/{test_number:03d}_15deg/results/batch_results_{test_number:03d}_{phase}_{number_of_iterations}iter.txt\'\n")

        elif phase == 'beta':        
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'/analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}_{phase}.par'"
                f" {number_of_iterations} 13 "
                f"'/analysis/diamond_2017/{test_number:03d}_15deg/{test_number:03d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'/analysis/diamond_2017/{test_number:03d}_15deg/results/batch_results_{test_number:03d}_{phase}_{number_of_iterations}iter.txt\'\n")

    print(".ins file written.")

# %%
# test number
test_number = 65

# number of refinement iterations
number_of_iterations = 20

# which phase is being refined?
phase = 'alpha'

# number and spacing of files
start = 3100
end = 3400


step = 1

create_ins_file_mac(start, end, step, test_number, phase, number_of_iterations)
# Out:
# .ins file written.

# %% [markdown]
# ## 4.2 Write an instruction file for the batch mode for Windows OS

# %% [markdown]
# To run the analysis in batch mode, an instruction file is required to tell MAUD exactly what analysis to do. This section writes the .ins file.
#
# The number 13 corresponds to the refinement analysis in MAUD (texture mode). The number of iterations sets how many times to run the refinement on each sample.
#
# **In Windows OS, we require an absolute file path for the analysis file in the instruction .ins file.**
#
# *Note, in multi-phase spectra only one phase can be refined at a time. In dual-phase Ti alloys, the alpha-phase is refined first, followed by the beta. *

# %%
def create_ins_file_windows(start: int, end: int, step: int, test_number: int, phase: str, number_of_iterations: int, 
                            file_path: str):
    """This function creates a '.ins' instruction file for running MAUD in batch mode.
    """
    # name of instruction file
    output_batch_path = pathlib.Path(f"../MAUD_batch_WinOS_{test_number:03d}_{phase}_{number_of_iterations}iter.ins")

    with output_batch_path.open(mode='w') as output_batch_file:

        output_batch_file.write('loop_\n'
        '    _riet_analysis_file\n'
        '    _riet_analysis_iteration_number\n'
        '    _riet_analysis_wizard_index\n'
        '    _riet_analysis_fileToSave\n'
        '    _riet_append_simple_result_to\n\n')
        # note, _riet_meas_datafile_name\n removed from above for swapping the data files.
        # note, _riet_append_result_to\n removed as this only prints out Rwp value.

        if phase == 'alpha':
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'{file_path}/analysis/{test_number:03d}/MAUD_{test_number:03d}_{image_number:05d}.par' "
                f"{number_of_iterations} 13 'MAUD_{test_number:03d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'batch_results_{test_number:03d}_{phase}_{number_of_iterations}iter.txt\'\n")

        elif phase == 'beta':        
            for image_number in range (start, end + 1, step):
                output_batch_file.write(f"'{file_path}/analysis/{test_number:03d}/MAUD_{test_number:03d}_{image_number:05d}_{phase}.par' "
                f"{number_of_iterations} 13 'MAUD_{test_number:03d}_{image_number:05d}_{phase}_{number_of_iterations}iter.par' "
                f"'batch_results_{test_number:03d}_{phase}_{number_of_iterations}iter.txt\'\n")

    print(".ins file written.")

# %%
# test number
test_number = 65

# number of refinement iterations
number_of_iterations = 20

# which phase is being refined?
phase = 'alpha'

# number and spacing of files
start = 0
end = 10
step = 1

# what is the file path to the MAUD-batch-analysis folder?
file_path = 'D:/Chris Daniel/MAUD-batch-analysis' # forward or back slashes are fine for the file path as MAUD reads in both

create_ins_file_windows(start, end, step, test_number, phase, number_of_iterations, file_path)

# %% [markdown]
# ## 5.1 Running MAUD batch mode on Mac OS

# %% [markdown]
# Leave the instruction .ins file and a folder for the analysis (containing the newly created .par analysis files) in the smae location it was created from in this notebook, such as;
#
#
# **/Users/mbcx9cd4/Documents/GitHub/MAUD-batch-analysis/**
#
#
# _Note, be careful with using a dropbox folder such as /Users/mbcx9cd4/Dropbox\ \(Research\ Group\)/Lightform\ Postdoc/MAUD_
#
#
# In the terminal navigate to the hidden files within the maud.app using the command;
#
#
# **cd /Applications/Maud.app/Contents/Resources/Java**
#
#
# _Note, you can view these files by right clicking on show package contents._
#
#
# Then, run the command to start the batch mode;
#
#
# **java -mx2048M -cp Maud.jar:miscLib.jar:jgaec.jar:ij.jar com.radiographema.MaudText -f /Users/mbcx9cd4/Documents/GitHub/MAUD-batch-analysis/MAUD_batch_MacOS_103845_alpha_5iter.ins**
#
#
# - -mx2048M sets the memory to be used i.e. 512, 1024, 2048, etc.
# - Maud.jar:miscLib.jar:jgaec.jar:ij.jar is a class path to the jar files.
# - An absolute path to the instruction file must be given. MAUD reads in both forward or back slashes for the file path.
#
#
# The analysis should run automatically. However, sometimes, an *error* appears and the batch mode is cancelled. If this happens, run a command which looks for a file that doesn't exist. A pop-up window will then appear, navigate to the .ins instruction file and click open.
#
#
# The batch mode will then run, showing the refinements in the terminal and outputting the refined analysis files and a result text file.
#
# *Note, this was tested with MAUD Version 2.78 on Mac OS Catalina Version 10.15.5*

# %% [markdown]
# ## 5.2 Running MAUD batch mode on Windows OS

# %% [markdown]
# Leave the instruction .ins file and a folder for the analysis (containing the newly created .par analysis files) in the smae location it was created from in this notebook, such as;
#
#
# **D:/Chris Daniel/MAUD-batch-analysis/**
#
#
# _Note, be careful with using a dropbox folder such as /Users/mbcx9cd4/Dropbox\ \(Research\ Group\)/Lightform\ Postdoc/MAUD_
#
#
# Navigate to the MAUD package, for example;
#
#
# **D:/Chris Daniel/Maud**
#
#
# And place the following `maud_batch.bat` file here.
#
#
# This contains the command to start the batch mode;
#
#
# **jdk\bin\java -mx8192M -classpath lib/Maud.jar;lib/ij.jar;lib/jgap.jar;lib/Help.jar;lib/EsquiClient.jar;lib/com.github.tschoonj.xraylib.jar;lib/joone-engine.jar;lib/newt.all.jar;lib/jdic.jar;lib/jdom.jar;lib/sqlite-jdbc.jar;lib/jmol.jar;lib/jgaec.jar;lib$ar;lib/Files.jar;lib/xgridlib.jar;lib/xgridagent.jar;lib/jogl.all.jar;lib/Examples.jar;lib/commons-math.jar;lib/rome.jar;lib/nativewindow.all.jar;lib/Images.jar;lib/swingx.jar;lib/jdic_stub.jar;lib/MySQL-ConnectorJ.jar;lib/HTTPClient.jar;lib/miscLib.jar;lib/gluegen-rt.jar com.radiographema.MaudText -file "D:\Chris Daniel\MAUD-batch-analysis\MAUD_batch_WinOS_065_alpha_20iter.ins"**
#
#
# - -mx2048M sets the memory to be used i.e. 512, 1024, 2048, etc.
# - lib/Maud.jar;lib/ij.jar... is a class path to the jar files.
# - An absolute path to the instruction file must be given. MAUD reads in both forward or back slashes for the file path.
#
#
# The analysis should run automatically. However, sometimes, an *error* appears and the batch mode is cancelled. If this happens on Windows OS, it is not possible to run a command which looks for a file that doesn't exist, since the pop-up window does *not* appear as it does on Mac OS (I'm not sure why).
#
#
# The batch mode will then run, showing the refinements in the terminal and outputting the refined analysis files and a result text file.
#
#
# *Note, this was tested with MAUD Version 2.94 on Windows 7*

# %%
def create_maud_batch(test_number: int, phase: str, number_of_iterations: int, file_path: str):
    """This function creates a 'maud_batch.bat' batch file to start MAUD in batch mode.
    """
    # name of instruction file
    output_batch_path = pathlib.Path(f"../analysis/batch_files/maud_batch_{test_number:03d}_{phase}_{number_of_iterations}iter.bat")

    with output_batch_path.open(mode='w') as output_batch_file:

        output_batch_file.write(f"jdk\\bin\\java -mx8192M -classpath lib/Maud.jar;lib/ij.jar;lib/jgap.jar;lib/Help.jar;lib/EsquiClient.jar;lib/com.github.tschoonj.xraylib.jar;lib/joone-engine.jar;lib/newt.all.jar;lib/jdic.jar;lib/jdom.jar;lib/sqlite-jdbc.jar;lib/jmol.jar;lib/jgaec.jar;lib$ar;lib/Files.jar;lib/xgridlib.jar;lib/xgridagent.jar;lib/jogl.all.jar;lib/Examples.jar;lib/commons-math.jar;lib/rome.jar;lib/nativewindow.all.jar;lib/Images.jar;lib/swingx.jar;lib/jdic_stub.jar;lib/MySQL-ConnectorJ.jar;lib/HTTPClient.jar;lib/miscLib.jar;lib/gluegen-rt.jar com.radiographema.MaudText -file "
                                f"\"{file_path}/maud_batch_WinOS_{test_number:03d}_{phase}_{number_of_iterations}iter.ins\"")

    print(".bat file written to 'analysis/batch_files/' folder.")

# %%
# test number
test_number = 65

# number of refinement iterations
number_of_iterations = 10

# which phase is being refined?
phase = 'alpha'

# what is the file path to the MAUD-batch-analysis folder?
file_path = 'D:/Chris Daniel/MAUD-batch-analysis' # forward or back slashes are fine for the file path as MAUD reads in both

create_maud_batch(test_number, phase, number_of_iterations, file_path)

# %% [markdown]
# ## 6. Output many .par analysis files to refine the $\beta$ texture

# %%
def create_second_phase_pars(start: int, end: int, step: int, test_number: int, phase1: str, phase2: str,
                            number_of_iterations: int, output_folder: str):
    """This function reads in an analysis file in '.par' format, which has been refined in MAUD to calculate the 
    phase1 (e.g. alpha) texture. The results of the previous refinement of phase1 are deleted and a refinement
    for phase2 (e.g. beta) is turned on. The file is output in '.par' format for refinement using MAUD.
    """
    for image_number in tqdm(range(start, end + 1, step)):

        second_iteration = False

        # MAUD analysis file with refined alpha texture
        #input_par_path = f"{output_folder}/{test_number:06d}_{image_number:05d}_{phase1}_{number_of_iterations:01d}iter.par"
        input_par_path = f"{output_folder}/{test_number:03d}_{image_number:05d}_{phase1}_{number_of_iterations:02d}iter.par"
        
        # output MAUD analysis file for refining beta texture
        #output_par_path = f"{output_folder}/{test_number:06d}_{image_number:05d}_{phase2}.par"
        output_par_path = f"{output_folder}/{test_number:03d}_{image_number:05d}_{phase2}.par"

        with open(input_par_path, 'r') as template_par_file, open(output_par_path, 'w') as new_par_file:
            line = template_par_file.readline() 

            while line:
                # remove the max reflection plane indices from the previous refinement
                if '_refln_index_h _refln_index_k _refln_index_l _refln_F_squared_meas _refln_F_squared_calc \
_refln_F_squared_sigma' in line and second_iteration == False:
                    new_par_file.write(line.strip('\n'))
                    for i in range(0,33):
                        line = template_par_file.readline()
                    second_iteration = True

                # remove the max reflection plane indices from the previous refinement
                elif '_refln_index_h _refln_index_k _refln_index_l _refln_F_squared_meas _refln_F_squared_calc \
_refln_F_squared_sigma' in line and second_iteration == True:
                    new_par_file.write(line.strip('\n'))
                    for i in range(0,12):
                        line = template_par_file.readline()
                    second_iteration = False

                # set refinement of alpha ODF to false
                if '_rita_odf_refinable true' in line:
                    new_par_file.write('_rita_odf_refinable false\n')

                elif '#subordinateObject_none tex' in line:
                    for l in range (0, 7):
                        line = template_par_file.readline()
                    # write metadata for the top of the file
                    new_par_file.write('#subordinateObject_E-WIMV\n\n'
                    '_pd_proc_ls_pref_orient_corr \'E-WIMV\'\n\n'
                    '_rita_generate_symmetry none\n'
                    '_rita_wimv_sum_coincidence true\n'
                    '_rita_wimv_iteration_max 10\n'
                    '_rita_wimv_exponent 0.01\n'
                    '_rita_wimv_refl_min_int 0.001\n'
                    '_rita_wimv_odf_resolution 15.0\n'
                    '_rita_wimv_tube_projection true\n'
                    '_rita_wimv_store_ang_conv true\n'
                    '_rita_wimv_odf_coverage_% 0\n'
                    '_rita_odf_sharpness ?\n'
                    '_rita_wimv_phon_use ?\n'
                    '_rita_wimv_tube_weight 0.5\n'
                    '_rita_wimv_normalize_pole_figures false\n'
                    '_rita_wimv_weigths_exponent 0.5\n'
                    '_rita_odf_refinable true\n'
                    '_rita_wimv_refl_min_dspacing 0.0\n\n'
                    '#custom_object_odf\n'
                    'loop_\n'
                    '_rita_wimv_odf_values\n')

                    for i in range(0, 10):
                        for j in range(0, 10):
                            for k in range (0, 37):
                                new_par_file.write('1.0 ')
                            new_par_file.write('\n')  
                        new_par_file.write('\n')
                    new_par_file.write('\n')

                    new_par_file.write('#end_custom_object_odf\n\n\n'
                    '#end_subordinateObject_E-WIMV\n\n\n')

                # write the rest of the file
                else:
                    new_par_file.write(line)

                line = template_par_file.readline()

    print(f"Written {int((end + 1 - start) / step)} .par analysis files to '{output_folder}' folder.")

# %%
# test number is put in the name of the input and output file
test_number = 103845

# previous information for the input file
number_of_iterations = 5
phase1 = 'alpha'

# number and spacing of files to read
start = 346
end = 386
step = 1

# where the .esg files are written
output_folder = pathlib.Path(f"../analysis/diamond_2021/{test_number:06d}-stage-scan/15deg")

# which phase is being refined?
phase2 = 'beta'

create_second_phase_pars(start, end, step, test_number, phase1, phase2, 
                         number_of_iterations, output_folder)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=41.0), HTML(value='')))
# Written 41 .par analysis files to '../analysis/diamond_2021/103845-stage-scan/15deg' folder.

# %%
# test number is put in the name of the input and output file
test_number = 65

# previous information for the input file
number_of_iterations = 20
phase1 = 'alpha'

# number and spacing of files to read
start = 3100
end = 3400
step = 1

# where the .esg files are written
output_folder = pathlib.Path(f"../analysis/diamond_2017/{test_number:03d}_15deg")

# which phase is being refined?
phase2 = 'beta'

create_second_phase_pars(start, end, step, test_number, phase1, phase2, 
                         number_of_iterations, output_folder)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=301.0), HTML(value='')))
# Written 301 .par analysis files to '../analysis/diamond_2017/065_15deg' folder.

# %% [markdown]
# ## 7.1 Write an instruction file for refining the $\beta$ texture in batch mode for Mac OS

# %%
# user inputs

# test number
test_number = 65

# number of refinement iterations
number_of_iterations = 20

# which phase is being refined?
phase = 'beta'

# number and spacing of files
start = 3100
end = 3400
step = 1

create_ins_file_mac(start, end, step, test_number, phase, number_of_iterations)
# Out:
# .ins file written.

# %%
# test number
test_number = 103845

# number of refinement iterations
number_of_iterations = 5

# which phase is being refined?
phase = 'beta'

# number and spacing of files
start = 346
end = 386
step = 1

create_ins_file_mac(start, end, step, test_number, phase, number_of_iterations)
# Out:
# .ins file written.

# %% [markdown]
# ## 7.2 Write an instruction and batch file for refining the $\beta$ texture in batch mode for Windows OS

# %%
# test number
test_number = 65

# number of refinement iterations
number_of_iterations = 20

# which phase is being refined?
phase = 'beta'

# what is the file path to the MAUD-batch-analysis folder?
file_path = 'D:/Chris Daniel/MAUD-batch-analysis' # forward or back slashes are fine for the file path as MAUD reads in both

create_ins_file_windows(test_number, phase, number_of_iterations, file_path)

create_maud_batch(test_number, phase, number_of_iterations, file_path)
